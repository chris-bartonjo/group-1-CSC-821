# %%
def lsc(s1,s2): #function takes two strings
  m= len(s1) #length of s1
  n= len(s2) # length of s2

  # create and initializing a 2D table with 0
  dp=[[0]*(n+1) for _ in range(m+1)]

  #fill the table
  for i in range(1,m+1):
    for j in range(1,n+1):
      if s1[i-1]==s2[j-1]:
        dp[i][j]= dp[i-1][j-1]+1
      else:
        dp[i][j]=max(dp[i-1][j], dp[i][j-1])
  return dp[m][n]
#strings input by typing
s1=input("Enter first string: ")
s2=input("Enter second string:")
#print the longest Common Subsequence
print(f"length of LCS {lsc(s1,s2)}")
# Out:
# Enter first string: AGGTAB
# Enter second string:GXTXAYB
# length of LCS 4
