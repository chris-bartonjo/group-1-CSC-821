# %%
# Radix Sort using Counting Sort

def counting_sort(arr, exp):
    """
    Counting Sort according to the digit represented by exp.
    exp = 1   -> Ones place
    exp = 10  -> Tens place
    exp = 100 -> Hundreds place
    """

    n = len(arr)

    output = [0] * n
    count = [0] * 10

    # Count occurrences of each digit
    for i in range(n):
        index = (arr[i] // exp) % 10
        count[index] += 1

    # Convert count[] to cumulative count[]
    for i in range(1, 10):
        count[i] += count[i - 1]

    # Build output array (stable sort)
    """
    for i in range(n - 1, -1, -1):
        index = (arr[i] // exp) % 10
        output[count[index] - 1] = arr[i]
        count[index] -= 1
    """
    i = n - 1
    while i >= 0:
        index = arr[i] // exp
        output[count[index % 10] - 1] = arr[i]
        count[index % 10] -= 1
        i -= 1

    # Copy output back into original array
    i=0
    for i in range(0, len(arr)):
        arr[i] = output[i]
def radix_sort(arr):

    max_num = max(arr)

    exp = 1

    while max_num // exp > 0:
        counting_sort(arr, exp)

        if exp == 1:
            print(f"After sorting by Ones place : {arr}")

        elif exp == 10:
            print("After sorting by Tens place :", arr)

        elif exp == 100:
            print("After sorting by Hundreds place:", arr)

        exp *= 10

phone_numbers = [564, 213, 987, 432, 123, 765, 321, 654, 876]

print("Original List")
print(phone_numbers)

print("\nSorting Process")

radix_sort(phone_numbers)

print("\nFinal Sorted List")
print(phone_numbers)
# Out:
# Original List
# [564, 213, 987, 432, 123, 765, 321, 654, 876]
#
# Sorting Process
# After sorting by Ones place : [321, 432, 213, 123, 564, 654, 765, 876, 987]
# After sorting by Tens place : [213, 321, 123, 432, 654, 564, 765, 876, 987]
# After sorting by Hundreds place: [123, 213, 321, 432, 564, 654, 765, 876, 987]
#
# Final Sorted List
# [123, 213, 321, 432, 564, 654, 765, 876, 987]
